# %% [markdown]
# # Dutch national flag algorithm

# %%
# Statement: Given an array consisting of only 0s, 1s, and 2s. Write a program to in-place sort the array without using inbuilt sort functions.
# ( Expected: Single pass-O(N) and constant space)


# Examples
# Input: nums = [2,0,2,1,1,0]
# Output: [0,0,1,1,2,2]

# Input: nums = [2,0,1]
# Output: [0,1,2]

# Input: nums = [0]
# Output: [0]

#optimal
def sort(nums):
    low = 0
    mid = 0
    high = len(nums) - 1
    while(mid<=high):
        if nums[mid] == 0:
            nums[low], nums[mid] = nums[mid], nums[low]
            low+=1
            mid+=1
        elif nums[mid] == 1:
            mid+=1
        else:
            nums[mid], nums[high] = nums[high], nums[mid]
            high-=1

 
nums =  [2,0,2,1,1,0]
sort(nums)
nums
# Out:
# [0, 0, 1, 1, 2, 2]

# %%
def sortArray(arr):
    cnt0 = 0
    cnt1 = 1
    cnt2 = 2
    for i in arr:
        if i == 0:
            cnt0+=1
        elif i == 1:
            cnt1+=1
        else:
            cnt2+=1
    for i in range(cnt0):
        arr[i] = 0
    for i in range(cnt0, cnt0+cnt1):
        arr[i] = 1
    for i in range(cnt0+cnt1, len(arr)):
        arr[i] = 2
        


arr = [1,0,2,1,2,0,1,0]
sortArray(arr)
arr
# Out:
# [0, 0, 0, 1, 1, 1, 1, 2]
