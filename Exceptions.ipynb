# %%
a = 10
b = 5
try:
    print(a/b)
except Exception as e:
    print("Nothing")
# Out:
# 2.0

# %%
a = 10
b = 0
try:
    print(a/b)
except Exception as e:
    print("Nothing")
# Out:
# Nothing

# %%
a = int(input("Enter a number:"))
b = int(input("Enter a number:"))

try:
    print(a/b)
    

except Exception as e:
    print("we can't do that")
# Out:
# 0.5

# %%
try:
    a = 10
    b = vvxv
    print(a / b)
    print(b / a)

except Exception as e:
    print("dude it is shit!!")
    print(e)
# Out:
# dude it is shit!!
# name 'vvxv' is not defined

# %%
try:
    a = 10
    b = 2
    c = 4
    print(a / c)
    print("waste")
    

except Exception as e:
    print("dude it is shit!!")
    print(e)
    
finally:
    print("Really cool")
# Out:
# 2.5
# waste
# Really cool
